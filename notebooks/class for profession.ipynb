# %%
import pandas as pd

# %%
path = "/Users/maximerichard/dev/personal/finance_code/dfkhelper/lib/hero_score/class_for_profession/"
class_profession_stats_path = path + "class_profession_stats.csv"

class_profession_stats = pd.read_csv(class_profession_stats_path)
class_profession_stats
# Out:
#                    0                    1                          2  \
# 0                NaN               mining                  gardening
# 1   total-base-stats              str-end                    wis-vit
# 2                160  paladin-dreadknight                        NaN
# 3                155                  NaN                        NaN
# 4                150              dragoon                       sage
# 5                145    knight-darkknight                    paladin
# 6                140              warrior                        NaN
# 7                135                  NaN                   summoner
# 8                130                  NaN  priest-wizard-dreadknight
# 9                125               pirate                        NaN
# 10               120                  NaN                    dragoon
# 11               115          archer-monk                        NaN
# 12               110                  NaN             monk-darkknigh
# 13               105                  NaN                        NaN
# 14               100                thief                     knight
# 15                95             summoner                        NaN
# 16                90    priest-ninja-sage                      ninja
# 17                85                  NaN              warrior-thief
# 18                80               wizard                     pirate
# 19                75                  NaN                     archer
# 20                70                  NaN                        NaN
#
#                    3                     4
# 0           foraging               fishing
# 1            dex-int               lck-agi
# 2                NaN                   NaN
# 3                NaN                   NaN
# 4                NaN                   NaN
# 5                NaN                   NaN
# 6        dreadknight                 ninja
# 7                NaN                 thief
# 8      summoner-sage                  sage
# 9   darkknight-ninja                   NaN
# 10            archer           dreadknight
# 11           dragoon                   NaN
# 12            wizard               dragoon
# 13               NaN                   NaN
# 14            priest                pirate
# 15               NaN                   NaN
# 16    warrior-pirate  archer-monk-summoner
# 17              monk               warrior
# 18             thief  wizard-priest-knight
# 19            knight               paladin
# 20           paladin            darkknight

# %%
rank_heros
